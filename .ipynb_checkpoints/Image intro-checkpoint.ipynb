# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
pic = Image.open('sample dataset\hummingBird.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=670x344 at 0x219F49A5D60>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
pic_arr.shape
#3 is the color layer
# 0 - Red
# 1 - Green
# 2 - Blue
# Out:
# (344, 670, 3)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
plt.imshow(pic)

# %%
pic_cpy = pic_arr.copy()

# %%
plt.imshow(pic_cpy[:,:,0])

# %%
plt.imshow(pic_cpy[:,:,1])

# %%
plt.imshow(pic_cpy[:,:,2])

# %%
#cmap - color map
print(plt.imshow(pic_cpy[:,:,0],cmap='gray'))
# Out:
# AxesImage(54,36;334.8x217.44)
